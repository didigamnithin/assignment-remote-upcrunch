# %%
import pandas as pd

# Read CSV into DataFrame
df = pd.read_csv("upchurch doordash marketing.csv")

# Loop through each column and print value counts
for col in df.columns:
    print(f"\nValue counts for column: {col}")
    print(df[col].value_counts())
# Out:
# Value counts for column: Date
# Date
# 2025-07-25    126
# 2025-07-23    126
# 2025-07-27    123
# 2025-07-26    122
# 2025-07-08    121
#              ...
# 2025-06-30     17
# 2025-06-29     17
# 2025-06-03     15
# 2025-06-17     13
# 2025-06-02     11
# Name: count, Length: 72, dtype: int64
#
# Value counts for column: Is Self Serve Campaign
# Is Self Serve Campaign
# False    3284
# True     1694
# Name: count, dtype: int64
#
# Value counts for column: Campaign ID
# Campaign ID
# 1b644e69-41a3-4172-813d-0097feb51d88    616
# e447ee04-f112-4caf-b6da-8a98285639f4    592
# 4eba9762-786f-4fc4-aede-412b8bdcb990    491
# 39f7b426-91f8-470c-8bea-ab3e9e4e52e4    387
# 3c79c2fd-3483-474a-9c26-8a39c02a628d    334
# 64037fd1-de6c-4ed7-9f08-3b0e5eac5333    331
# 2d098b94-d85b-4a8e-b16b-9f61449e9b25    286
# 1ab90f22-4581-4ef6-9a8b-01ded258aa62    224
# bf2b58eb-cf63-4f66-844c-65e2fdb9e340    201
# f2ca985c-bafd-4334-99d6-75d17407797f    192
# d5d9897e-eded-4f8d-a794-29f6e7aa9f24    192
# ...

# %%
unique_cols = [col for col in df.columns if df[col].nunique() == len(df)]

print("Columns with all unique values:", unique_cols)
# Out:
# Columns with all unique values: []
